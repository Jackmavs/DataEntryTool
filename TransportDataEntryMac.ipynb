# %%
import tkinter as tk
import openpyxl
import os
from tkmacosx import Button
from functools import partial

# %%
# Surveyor = 'Name'
# Location = '1'
# Site = 'xxx'
# Date = 'xx/xx/xxxx'
# Peak = '1' #Morning Peak:1, Morning Peak off:2, Afternoon Peak:3, Night:4 
# Weather = '1' #Sunny:1, Cloudy:2, Rainy:3, Windy:4,

# %%
win = tk.Tk()
win.title('Transport Survey')
win.geometry('800x400+200+200')
# label = tk.LabelFrame(win, text = 'Name of Surveyor: '+Surveyor+'\nLocation: '+Site+'\nRussel St'+Location+'\nDate: '+Date+'\nPeak: '+Peak+'\nWeather: '+Weather)
# label.pack(side='top', fill='both', expand=True)
        
label_name = tk.Label(win, text = 'Name: ')
label_name.grid(row=0, column=0)

entry_name = tk.Entry(win, width = 20)
entry_name.grid(row=0, column=1)
entry_name.insert(0, 'Jack')

label_location = tk.Label(win, text = 'Location (1-4): ')
label_location.grid(row=0, column=2)

entry_location = tk.Entry(win, width = 20)
entry_location.grid(row=0, column=3)
entry_location.insert(0, '1')

label_site = tk.Label(win, text = 'Site: ')
label_site.grid(row=1, column=0)

entry_site = tk.Entry(win, width = 20)
entry_site.grid(row=1, column=1)
entry_site.insert(0, 'xxx St')

label_date = tk.Label(win, text = 'Date: ')
label_date.grid(row=1, column=2)

entry_date = tk.Entry(win, width = 20)
entry_date.grid(row=1, column=3)
entry_date.insert(0, '01/01/2023')

label_peak = tk.Label(win, text = 'Peak (1-4): ')
label_peak.grid(row=2, column=0)

entry_peak = tk.Entry(win, width = 20)
entry_peak.grid(row=2, column=1)
entry_peak.insert(0, '1')

label_weather = tk.Label(win, text = 'Weather (1-4): ')
label_weather.grid(row=2, column=2)

entry_weather = tk.Entry(win, width = 20)
entry_weather.grid(row=2, column=3)
entry_weather.insert(0, '1')

# %%
def safePath():
    if button1["bg"] != 'red' and button2["bg"] != 'red':
        button1["bg"] = 'red'
    elif button1["bg"] != 'red' and button2["bg"] == 'red':
        button1["bg"] = 'red'
        button2["bg"] = '#F0F0F0'
    elif button1["bg"] == 'red' and button2["bg"] != 'red':
        button1["bg"] = '#F0F0F0'
    return None

def shortestPath():
    if button2["bg"] != 'red' and button1["bg"] != 'red':
        button2["bg"] = 'red'
    elif button2["bg"] != 'red' and button1["bg"] == 'red':
        button2["bg"] = 'red'
        button1["bg"] = '#F0F0F0'
    elif button2["bg"] == 'red' and button1["bg"] != 'red':
        button2["bg"] = '#F0F0F0'
    return None

def femaleGender():
    if button3["bg"] != 'red' and button4["bg"] != 'red':
        button3["bg"] = 'red'
    elif button3["bg"] != 'red' and button4["bg"] == 'red':
        button3["bg"] = 'red'
        button4["bg"] = '#F0F0F0'
    elif button3["bg"] == 'red' and button4["bg"] != 'red':
        button3["bg"] = '#F0F0F0'
    return None

def maleGender():
    if button4["bg"] != 'red' and button3["bg"] != 'red':
        button4["bg"] = 'red'
    elif button4["bg"] != 'red' and button3["bg"] == 'red':
        button4["bg"] = 'red'
        button3["bg"] = '#F0F0F0'
    elif button4["bg"] == 'red' and button3["bg"] != 'red':
        button4["bg"] = '#F0F0F0'
    return None

def youngerAge():
    if button5["bg"] != 'red' and button6["bg"] != 'red' and button7["bg"] != 'red' and button8["bg"] != 'red':
        button5["bg"] = 'red'
    elif button5["bg"] != 'red' and button6["bg"] == 'red' or button5["bg"] != 'red' and button7["bg"] == 'red' or button5["bg"] != 'red' and button8["bg"] == 'red':
        button5["bg"] = 'red'
        button6["bg"] = '#F0F0F0'
        button7["bg"] = '#F0F0F0'
        button8["bg"] = '#F0F0F0'
    elif button5["bg"] == 'red' and button6["bg"] != 'red' and button7["bg"] != 'red' and button8["bg"] != 'red':
        button5["bg"] = '#F0F0F0'
    return None

def youngAge():
    if button6["bg"] != 'red' and button5["bg"] != 'red' and button7["bg"] != 'red' and button8["bg"] != 'red':
        button6["bg"] = 'red'
    elif button6["bg"] != 'red' and button5["bg"] == 'red' or button6["bg"] != 'red' and button7["bg"] == 'red' or button6["bg"] != 'red' and button8["bg"] == 'red':
        button6["bg"] = 'red'
        button5["bg"] = '#F0F0F0'
        button7["bg"] = '#F0F0F0'
        button8["bg"] = '#F0F0F0'
    elif button6["bg"] == 'red' and button5["bg"] != 'red' and button7["bg"] != 'red' and button8["bg"] != 'red':
        button6["bg"] = '#F0F0F0'
    return None

def midAge():
    if button7["bg"] != 'red' and button6["bg"] != 'red' and button5["bg"] != 'red' and button8["bg"] != 'red':
        button7["bg"] = 'red'
    elif button7["bg"] != 'red' and button6["bg"] == 'red' or button7["bg"] != 'red' and button5["bg"] == 'red' or button7["bg"] != 'red' and button8["bg"] == 'red':
        button7["bg"] = 'red'
        button6["bg"] = '#F0F0F0'
        button5["bg"] = '#F0F0F0'
        button8["bg"] = '#F0F0F0'
    elif button7["bg"] == 'red' and button6["bg"] != 'red' and button5["bg"] != 'red' and button8["bg"] != 'red':
        button7["bg"] = '#F0F0F0'
    return None

def seniorAge():
    if button8["bg"] != 'red' and button6["bg"] != 'red' and button7["bg"] != 'red' and button5["bg"] != 'red':
        button8["bg"] = 'red'
    elif button8["bg"] != 'red' and button6["bg"] == 'red' or button8["bg"] != 'red' and button7["bg"] == 'red' or button8["bg"] != 'red' and button5["bg"] == 'red':
        button8["bg"] = 'red'
        button6["bg"] = '#F0F0F0'
        button7["bg"] = '#F0F0F0'
        button5["bg"] = '#F0F0F0'
    elif button8["bg"] == 'red' and button6["bg"] != 'red' and button7["bg"] != 'red' and button5["bg"] != 'red':
        button8["bg"] = '#F0F0F0'
    return None

def disableMove():
    if button9["bg"] != 'red':
        button9["bg"] = 'red'
    else:
        button9["bg"] = '#F0F0F0'
    return None

def impairmentMove():
    if button10["bg"] != 'red':
        button10["bg"] = 'red'
    else:
        button10["bg"] = '#F0F0F0'
    return None

def pramTake():
    if button11["bg"] != 'red':
        button11["bg"] = 'red'
    else:
        button11["bg"] = '#F0F0F0'
    return None

def childrenTake():
    if button12["bg"] != 'red':
        button12["bg"] = 'red'
    else:
        button12["bg"] = '#F0F0F0'
    return None

def petTake():
    if button13["bg"] != 'red':
        button13["bg"] = 'red'
    else:
        button13["bg"] = '#F0F0F0'
    return None

def bagTake():
    if button14["bg"] != 'red':
        button14["bg"] = 'red'
    else:
        button14["bg"] = '#F0F0F0'
    return None

def bussinessLook():
    if button15["bg"] != 'red':
        button15["bg"] = 'red'
    else:
        button15["bg"] = '#F0F0F0'
    return None

def overfitLook():
    if button16["bg"] != 'red':
        button16["bg"] = 'red'
    else:
        button16["bg"] = '#F0F0F0'
    return None

def fastWalk():
    if button17["bg"] != 'red':
        button17["bg"] = 'red'
    else:
        button17["bg"] = '#F0F0F0'
    return None

def runningWalk():
    if button18["bg"] != 'red':
        button18["bg"] = 'red'
    else:
        button18["bg"] = '#F0F0F0'
    return None

def somebodyWalk():
    if button19["bg"] != 'red':
        button19["bg"] = 'red'
    else:
        button19["bg"] = '#F0F0F0'
    return None

def phoneWalk():
    if button20["bg"] != 'red':
        button20["bg"] = 'red'
    else:
        button20["bg"] = '#F0F0F0'
    return None

def flowWith():
    if button21["bg"] != 'red':
        button21["bg"] = 'red'
    else:
        button21["bg"] = '#F0F0F0'
    return None

def flowAgainst():
    if button22["bg"] != 'red':
        button22["bg"] = 'red'
    else:
        button22["bg"] = '#F0F0F0'
    return None

# %%
def nextPerson():
    Name = entry_name.get()
    Site = entry_site.get()
    Location = entry_location.get()
    Date = entry_date.get()
    Peak = entry_peak.get()
    Weather = entry_weather.get()
    
    total_list = []
    total_list.append(Site)
    try:
        total_list.append(int(Location))
        try:
            label_location.destroy()
        except:
            pass
    except:
        label_location = tk.Label(win, text = 'Location should be number').grid(row=11, column=0)
        return None
    total_list.append(Date)
    
    if Peak == '1' or Peak == '2' or Peak == '3' or Peak == '4':
        try:
            label_peak.destroy()
        except:
            pass
        
        if int(Peak) == 1:
            total_list.append(1)
            total_list.append('')
            total_list.append('')
            total_list.append('')
        elif int(Peak) == 2:
            total_list.append('')
            total_list.append(1)
            total_list.append('')
            total_list.append('')
        elif int(Peak) == 3:
            total_list.append('')
            total_list.append('')
            total_list.append(1)
            total_list.append('')
        elif int(Peak) == 4:
            total_list.append('')
            total_list.append('')
            total_list.append('')
            total_list.append(1)
    else:
        label_peak = tk.Label(win, text = 'Peak should be 1-4').grid(row=12, column=0)
        return None
        
    if Weather == '1' or Weather == '2' or Weather == '3' or Weather == '4':
        try:
            label_weather.destroy()
        except:
            pass
        if int(Weather) == 1:
            total_list.append(1)
            total_list.append('')
            total_list.append('')
            total_list.append('')
        elif int(Weather) == 2:
            total_list.append('')
            total_list.append(1)
            total_list.append('')
            total_list.append('')
        elif int(Weather) == 3:
            total_list.append('')
            total_list.append('')
            total_list.append(1)
            total_list.append('')
        elif int(Weather) == 4:
            total_list.append('')
            total_list.append('')
            total_list.append('')
            total_list.append(1)
    else:
        label_weather = tk.Label(win, text = 'Weather should be 1-4').grid(row=13, column=0)
        return None
        
    if button1["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button2["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button3["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button4["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button5["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button6["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button7["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button8["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button9["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button10["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button11["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button12["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button13["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button14["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button15["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button16["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button17["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button18["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button19["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button20["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button21["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button22["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    wb = openpyxl.load_workbook('worksheet1.xlsx')
    ws = wb.active
    ws.append(total_list)
    wb.save('worksheet1.xlsx')
    
    button1["bg"] = '#F0F0F0'
    button2["bg"] = '#F0F0F0'
    button3["bg"] = '#F0F0F0'
    button4["bg"] = '#F0F0F0'
    button5["bg"] = '#F0F0F0'
    button6["bg"] = '#F0F0F0'
    button7["bg"] = '#F0F0F0'
    button8["bg"] = '#F0F0F0'
    button9["bg"] = '#F0F0F0'
    button10["bg"] = '#F0F0F0'
    button11["bg"] = '#F0F0F0'
    button12["bg"] = '#F0F0F0'
    button13["bg"] = '#F0F0F0'
    button14["bg"] = '#F0F0F0'
    button15["bg"] = '#F0F0F0'
    button16["bg"] = '#F0F0F0'
    button17["bg"] = '#F0F0F0'
    button18["bg"] = '#F0F0F0'
    button19["bg"] = '#F0F0F0'
    button20["bg"] = '#F0F0F0'
    button21["bg"] = '#F0F0F0'
    button22["bg"] = '#F0F0F0'
    
    entry_name.delete(0, 'end')
    entry_location.delete(0, 'end')
    entry_site.delete(0, 'end')
    entry_date.delete(0, 'end')
    entry_peak.delete(0, 'end')
    entry_weather.delete(0, 'end')  
    entry_name.insert(0, Name)
    entry_location.insert(0, Location)
    entry_site.insert(0, Site)
    entry_date.insert(0, Date)
    entry_peak.insert(0, Peak)
    entry_weather.insert(0, Weather)
    
    return None

# %%
button1 = Button(win, text = 'Designated safe path', command = safePath)
button1.grid(row=3, column=0)
button2 = Button(win, text = 'Shortest path', command = shortestPath)
button2.grid(row=3, column=1)

button3 = Button(win, text = 'Female', command = femaleGender)
button3.grid(row=4, column=0)
button4 = Button(win, text = 'Male', command = maleGender)
button4.grid(row=4, column=1)

button5 = Button(win, text = 'Younger than 18', command = youngerAge)
button5.grid(row=5, column=0)
button6 = Button(win, text = 'Young (18-30 years)', command = youngAge)
button6.grid(row=5, column=1)
button7 = Button(win, text = 'Mid-age (30-65 years)', command = midAge)
button7.grid(row=5, column=2)
button8 = Button(win, text = 'Senior (65 years and over)', command = seniorAge)
button8.grid(row=5, column=3)

button9 = Button(win, text = 'Disable', command = disableMove)
button9.grid(row=6, column=0)
button10 = Button(win, text = 'Mobility impairment', command = impairmentMove)
button10.grid(row=6, column=1)
button11 = Button(win, text = 'Pram/trolley', command = pramTake)
button11.grid(row=6, column=0)
button12 = Button(win, text = 'Walking with small children', command = childrenTake)
button12.grid(row=6, column=1)
button13 = Button(win, text = 'Walking with pet', command = petTake)
button13.grid(row=6, column=2)
button14 = Button(win, text = 'Carrying a heavy bag', command = bagTake)
button14.grid(row=6, column=3)
button15 = Button(win, text = 'Bussiness/formal attire', command = bussinessLook)
button15.grid(row=7, column=0)
button16 = Button(win, text = 'Physically overfit', command = overfitLook)
button16.grid(row=7, column=1)
button17 = Button(win, text = 'Walking fast', command = fastWalk)
button17.grid(row=8, column=0)
button18 = Button(win, text = 'Running', command = runningWalk)
button18.grid(row=8, column=1)
button19 = Button(win, text = 'Walking with somebody', command = somebodyWalk)
button19.grid(row=9, column=0)
button20 = Button(win, text = 'Moblie phone use', command = phoneWalk)
button20.grid(row=9, column=1)
button21 = Button(win, text = 'Flow with', command = flowWith)
button21.grid(row=10, column=0)
button22 = Button(win, text = 'Flow against', command = flowAgainst)
button22.grid(row=10, column=1)

button23 = Button(win, text = 'Next', command = nextPerson)
button23.grid(row=11, column=3)

# %%
win.mainloop()
