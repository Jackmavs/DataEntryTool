# %%
import tkinter as tk
import openpyxl
from tkmacosx import Button
import os

# %%
Surveyor = 'Yuanjie Wang'
Location = 'Russel St'
Date = '03/02/2023'
Peak = '3'
Weather = 'Sunny'

# %%
win = tk.Tk()
win.title('Transport Survey')
win.geometry('800x400+200+200')
label = tk.LabelFrame(win, text = 'Name of Surveyor: '+Surveyor+'\nLocation: '+Location+'\nDate: '+Date+'\nPeak: '+Peak+'\nWeather: '+Weather)
label.pack(side='top', fill='both', expand=True)

# %%
def safePath():
    if button1["bg"] != 'red' and button2["bg"] != 'red':
        button1["bg"] = 'red'
    elif button1["bg"] != 'red' and button2["bg"] == 'red':
        button1["bg"] = 'red'
        button2["bg"] = '#F0F0F0'
    elif button1["bg"] == 'red' and button2["bg"] != 'red':
        button1["bg"] = '#F0F0F0'
    return None

def shortestPath():
    if button2["bg"] != 'red' and button1["bg"] != 'red':
        button2["bg"] = 'red'
    elif button2["bg"] != 'red' and button1["bg"] == 'red':
        button2["bg"] = 'red'
        button1["bg"] = '#F0F0F0'
    elif button2["bg"] == 'red' and button1["bg"] != 'red':
        button2["bg"] = '#F0F0F0'
    return None

def femaleGender():
    if button3["bg"] != 'red' and button4["bg"] != 'red':
        button3["bg"] = 'red'
    elif button3["bg"] != 'red' and button4["bg"] == 'red':
        button3["bg"] = 'red'
        button4["bg"] = '#F0F0F0'
    elif button3["bg"] == 'red' and button4["bg"] != 'red':
        button3["bg"] = '#F0F0F0'
    return None

def maleGender():
    if button4["bg"] != 'red' and button3["bg"] != 'red':
        button4["bg"] = 'red'
    elif button4["bg"] != 'red' and button3["bg"] == 'red':
        button4["bg"] = 'red'
        button3["bg"] = '#F0F0F0'
    elif button4["bg"] == 'red' and button3["bg"] != 'red':
        button4["bg"] = '#F0F0F0'
    return None

def youngerAge():
    if button5["bg"] != 'red' and button6["bg"] != 'red' and button7["bg"] != 'red' and button8["bg"] != 'red':
        button5["bg"] = 'red'
    elif button5["bg"] != 'red' and button6["bg"] == 'red' or button5["bg"] != 'red' and button7["bg"] == 'red' or button5["bg"] != 'red' and button8["bg"] == 'red':
        button5["bg"] = 'red'
        button6["bg"] = '#F0F0F0'
        button7["bg"] = '#F0F0F0'
        button8["bg"] = '#F0F0F0'
    elif button5["bg"] == 'red' and button6["bg"] != 'red' and button7["bg"] != 'red' and button8["bg"] != 'red':
        button5["bg"] = '#F0F0F0'
    return None

def youngAge():
    if button6["bg"] != 'red' and button5["bg"] != 'red' and button7["bg"] != 'red' and button8["bg"] != 'red':
        button6["bg"] = 'red'
    elif button6["bg"] != 'red' and button5["bg"] == 'red' or button6["bg"] != 'red' and button7["bg"] == 'red' or button6["bg"] != 'red' and button8["bg"] == 'red':
        button6["bg"] = 'red'
        button5["bg"] = '#F0F0F0'
        button7["bg"] = '#F0F0F0'
        button8["bg"] = '#F0F0F0'
    elif button6["bg"] == 'red' and button5["bg"] != 'red' and button7["bg"] != 'red' and button8["bg"] != 'red':
        button6["bg"] = '#F0F0F0'
    return None

def midAge():
    if button7["bg"] != 'red' and button6["bg"] != 'red' and button5["bg"] != 'red' and button8["bg"] != 'red':
        button7["bg"] = 'red'
    elif button7["bg"] != 'red' and button6["bg"] == 'red' or button7["bg"] != 'red' and button5["bg"] == 'red' or button7["bg"] != 'red' and button8["bg"] == 'red':
        button7["bg"] = 'red'
        button6["bg"] = '#F0F0F0'
        button5["bg"] = '#F0F0F0'
        button8["bg"] = '#F0F0F0'
    elif button7["bg"] == 'red' and button6["bg"] != 'red' and button5["bg"] != 'red' and button8["bg"] != 'red':
        button7["bg"] = '#F0F0F0'
    return None

def seniorAge():
    if button8["bg"] != 'red' and button6["bg"] != 'red' and button7["bg"] != 'red' and button5["bg"] != 'red':
        button8["bg"] = 'red'
    elif button8["bg"] != 'red' and button6["bg"] == 'red' or button8["bg"] != 'red' and button7["bg"] == 'red' or button8["bg"] != 'red' and button5["bg"] == 'red':
        button8["bg"] = 'red'
        button6["bg"] = '#F0F0F0'
        button7["bg"] = '#F0F0F0'
        button5["bg"] = '#F0F0F0'
    elif button8["bg"] == 'red' and button6["bg"] != 'red' and button7["bg"] != 'red' and button5["bg"] != 'red':
        button8["bg"] = '#F0F0F0'
    return None

def disableMove():
    if button9["bg"] != 'red':
        button9["bg"] = 'red'
    else:
        button9["bg"] = '#F0F0F0'
    return None

def impairmentMove():
    if button10["bg"] != 'red':
        button10["bg"] = 'red'
    else:
        button10["bg"] = '#F0F0F0'
    return None

def pramTake():
    if button11["bg"] != 'red':
        button11["bg"] = 'red'
    else:
        button11["bg"] = '#F0F0F0'
    return None

def childrenTake():
    if button12["bg"] != 'red':
        button12["bg"] = 'red'
    else:
        button12["bg"] = '#F0F0F0'
    return None

def petTake():
    if button13["bg"] != 'red':
        button13["bg"] = 'red'
    else:
        button13["bg"] = '#F0F0F0'
    return None

def bagTake():
    if button14["bg"] != 'red':
        button14["bg"] = 'red'
    else:
        button14["bg"] = '#F0F0F0'
    return None

def bussinessLook():
    if button15["bg"] != 'red':
        button15["bg"] = 'red'
    else:
        button15["bg"] = '#F0F0F0'
    return None

def overfitLook():
    if button16["bg"] != 'red':
        button16["bg"] = 'red'
    else:
        button16["bg"] = '#F0F0F0'
    return None

def fastWalk():
    if button17["bg"] != 'red':
        button17["bg"] = 'red'
    else:
        button17["bg"] = '#F0F0F0'
    return None

def runningWalk():
    if button18["bg"] != 'red':
        button18["bg"] = 'red'
    else:
        button18["bg"] = '#F0F0F0'
    return None

def somebodyWalk():
    if button19["bg"] != 'red':
        button19["bg"] = 'red'
    else:
        button19["bg"] = '#F0F0F0'
    return None

def phoneWalk():
    if button20["bg"] != 'red':
        button20["bg"] = 'red'
    else:
        button20["bg"] = '#F0F0F0'
    return None

def flowWith():
    if button21["bg"] != 'red':
        button21["bg"] = 'red'
    else:
        button21["bg"] = '#F0F0F0'
    return None

def flowAgainst():
    if button22["bg"] != 'red':
        button22["bg"] = 'red'
    else:
        button22["bg"] = '#F0F0F0'
    return None

# %%
def nextPerson():
    total_list = []
    if button1["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button2["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button3["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button4["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button5["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button6["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button7["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button8["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button9["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button10["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button11["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    
    if button12["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button13["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button14["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button15["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button16["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button17["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button18["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button19["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button20["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button21["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
        
    if button22["bg"] == 'red':
        total_list.append(1)
    else:
        total_list.append('')
    wb = openpyxl.load_workbook('worksheet.xlsx')
    ws = wb.active
    ws.append(total_list)
    wb.save('worksheet.xlsx')
    button1["bg"] = '#F0F0F0'
    button2["bg"] = '#F0F0F0'
    button3["bg"] = '#F0F0F0'
    button4["bg"] = '#F0F0F0'
    button5["bg"] = '#F0F0F0'
    button6["bg"] = '#F0F0F0'
    button7["bg"] = '#F0F0F0'
    button8["bg"] = '#F0F0F0'
    button9["bg"] = '#F0F0F0'
    button10["bg"] = '#F0F0F0'
    button11["bg"] = '#F0F0F0'
    button12["bg"] = '#F0F0F0'
    button13["bg"] = '#F0F0F0'
    button14["bg"] = '#F0F0F0'
    button15["bg"] = '#F0F0F0'
    button16["bg"] = '#F0F0F0'
    button17["bg"] = '#F0F0F0'
    button18["bg"] = '#F0F0F0'
    button19["bg"] = '#F0F0F0'
    button20["bg"] = '#F0F0F0'
    button21["bg"] = '#F0F0F0'
    button22["bg"] = '#F0F0F0'
    return None

# %%
# button1 = tk.Button(label, text = 'Designated safe path', command = safePath)
# button1.grid(row=0, column=0)
# button2 = tk.Button(label, text = 'Shortest path', command = shortestPath)
# button2.grid(row=0, column=1)

# button3 = tk.Button(label, text = 'Female', command = femaleGender)
# button3.grid(row=1, column=0)
# button4 = tk.Button(label, text = 'Male', command = maleGender)
# button4.grid(row=1, column=1)

# button5 = tk.Button(label, text = 'Younger than 18', command = youngerAge)
# button5.grid(row=2, column=0)
# button6 = tk.Button(label, text = 'Young (18-30 years)', command = youngAge)
# button6.grid(row=2, column=1)
# button7 = tk.Button(label, text = 'Mid-age (30-65 years)', command = midAge)
# button7.grid(row=2, column=2)
# button8 = tk.Button(label, text = 'Senior (65 years and over)', command = seniorAge)
# button8.grid(row=2, column=3)

# button9 = tk.Button(label, text = 'Disable', command = disableMove)
# button9.grid(row=3, column=0)
# button10 = tk.Button(label, text = 'Mobility impairment', command = impairmentMove)
# button10.grid(row=3, column=1)
# button11 = tk.Button(label, text = 'Pram/trolley', command = pramTake)
# button11.grid(row=4, column=0)
# button12 = tk.Button(label, text = 'Walking with small children', command = childrenTake)
# button12.grid(row=4, column=1)
# button13 = tk.Button(label, text = 'Walking with pet', command = petTake)
# button13.grid(row=4, column=2)
# button14 = tk.Button(label, text = 'Carrying a heavy bag', command = bagTake)
# button14.grid(row=4, column=3)
# button15 = tk.Button(label, text = 'Bussiness/formal attire', command = bussinessLook)
# button15.grid(row=5, column=0)
# button16 = tk.Button(label, text = 'Physically overfit', command = overfitLook)
# button16.grid(row=5, column=1)
# button17 = tk.Button(label, text = 'Walking fast', command = fastWalk)
# button17.grid(row=6, column=0)
# button18 = tk.Button(label, text = 'Running', command = runningWalk)
# button18.grid(row=6, column=1)
# button19 = tk.Button(label, text = 'Walking with somebody', command = somebodyWalk)
# button19.grid(row=7, column=0)
# button20 = tk.Button(label, text = 'Moblie phone use', command = phoneWalk)
# button20.grid(row=7, column=1)
# button21 = tk.Button(label, text = 'Flow with', command = flowWith)
# button21.grid(row=8, column=0)
# button22 = tk.Button(label, text = 'Flow against', command = flowAgainst)
# button22.grid(row=8, column=1)

# button23 = tk.Button(label, text = 'Next', command = nextPerson)
# button23.grid(row=9, column=3)

button1 = Button(label, text = 'Designated safe path', command = safePath)
button1.grid(row=0, column=0)
button2 = Button(label, text = 'Shortest path', command = shortestPath)
button2.grid(row=0, column=1)

button3 = Button(label, text = 'Female', command = femaleGender)
button3.grid(row=1, column=0)
button4 = Button(label, text = 'Male', command = maleGender)
button4.grid(row=1, column=1)

button5 = Button(label, text = 'Younger than 18', command = youngerAge)
button5.grid(row=2, column=0)
button6 = Button(label, text = 'Young (18-30 years)', command = youngAge)
button6.grid(row=2, column=1)
button7 = Button(label, text = 'Mid-age (30-65 years)', command = midAge)
button7.grid(row=2, column=2)
button8 = Button(label, text = 'Senior (65 years and over)', command = seniorAge)
button8.grid(row=2, column=3)

button9 = Button(label, text = 'Disable', command = disableMove)
button9.grid(row=3, column=0)
button10 = Button(label, text = 'Mobility impairment', command = impairmentMove)
button10.grid(row=3, column=1)
button11 = Button(label, text = 'Pram/trolley', command = pramTake)
button11.grid(row=4, column=0)
button12 = Button(label, text = 'Walking with small children', command = childrenTake)
button12.grid(row=4, column=1)
button13 = Button(label, text = 'Walking with pet', command = petTake)
button13.grid(row=4, column=2)
button14 = Button(label, text = 'Carrying a heavy bag', command = bagTake)
button14.grid(row=4, column=3)
button15 = Button(label, text = 'Bussiness/formal attire', command = bussinessLook)
button15.grid(row=5, column=0)
button16 = Button(label, text = 'Physically overfit', command = overfitLook)
button16.grid(row=5, column=1)
button17 = Button(label, text = 'Walking fast', command = fastWalk)
button17.grid(row=6, column=0)
button18 = Button(label, text = 'Running', command = runningWalk)
button18.grid(row=6, column=1)
button19 = Button(label, text = 'Walking with somebody', command = somebodyWalk)
button19.grid(row=7, column=0)
button20 = Button(label, text = 'Moblie phone use', command = phoneWalk)
button20.grid(row=7, column=1)
button21 = Button(label, text = 'Flow with', command = flowWith)
button21.grid(row=8, column=0)
button22 = Button(label, text = 'Flow against', command = flowAgainst)
button22.grid(row=8, column=1)

button23 = Button(label, text = 'Next', command = nextPerson)
button23.grid(row=9, column=3)

# %%
win.mainloop()
